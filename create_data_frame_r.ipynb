# %% [markdown]
# <a href="https://colab.research.google.com/github/rijalularif/Data-Analitik-Google/blob/main/create_data_frame_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
